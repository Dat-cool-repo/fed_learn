# %%
import importlib
import load_data as ld
import display_metrics as dm
importlib.reload(ld)

# Load in experiment results
folder_path = "../results"
runs = ld.load_experiment_folder(folder_path)
print(f"Loaded {len(runs)} runs")
ld.print_all_run_names(runs)

# Convert to dataframe
df = ld.runs_to_dataframe(runs)
# Out:
# Loaded 10 runs
# --- RUNS LOADED ---
#
# ('fedprox', 'lora', 'high', 0.3, 7)
#
# ('scaffold', 'lora', 'high', 0.3, 7)
#
# ('scaffold', 'lora', 'low', 0.3, 7)
#
# ('scaffold', 'soft_prompt', 'low', 0.3, 7)
#
# ('fedprox', 'soft_prompt', 'low', 0.3, 7)
#
# ('scaffold', 'soft_prompt', 'high', 0.3, 7)
#
# ('fedprox', 'soft_prompt', 'high', 0.3, 7)
#
# ('fedprox', 'lora', 'low', 0.3, 7)
#
# ('scaffold', 'soft_prompt', 'low', 0.3, 13)
#
# ('scaffold', 'lora', 'low', 0.3, 13)

# %%
importlib.reload(dm)

dm.plot_seed_variance(df, metric="val_loss", group_by="aggregation_method")
dm.plot_seed_variance(df, metric="val_loss", group_by="peft_method")

# %%
importlib.reload(dm)

# Aggregate across seeds
agg_df = dm.aggregate_across_seeds(df)

# Plot regressions
reg_df, reg_summary = dm.plot_regressions(
    df,
    metric="val_loss",
    group_by="aggregation_method"
)

# %%
importlib.reload(dm)

# Plot drift metrics
dm.plot_all(agg_df)
